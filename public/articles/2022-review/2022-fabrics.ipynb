# %% [markdown]
# # Outlier The Year in Fabrics &mdash; 2022

# %% [markdown]
# Accompaniment to Abe's [2022 &mdash; The Year in Fabrics](https://www.reddit.com/r/Outlier/comments/102dx05/2022_the_year_in_fabrics/)

# %%
import pandas as pd
import numpy as np
import scipy
import os
import os.path
from IPython.display import display, HTML
import utils
import plots
import altair as alt

year = 2022
df_all = utils.outlier_df('../../outlier-data.csv', year)
# df_all = utils.outlier_df('../../../outlier/public/outlier-data.csv', year)

# %%
# rel = df_all.iloc[0]['Release'].to_pydatetime()
# <i>(Provisional, containing drops up to {rel.strftime("%b %d, %Y")})</i></p>
text = f"""<p>A catalog of all drops from 2022, grouped by fabric, ordered by the number of drops in that fabric.<br />
"""
display(HTML(text))
# Out:
# <p>A catalog of all drops from 2022, grouped by fabric, ordered by the number of drops in that fabric.<br />

# %%
# Filter to Clothes
def type_to_kind(drop_type):
    if drop_type == "T-Shirt" or drop_type == "Shirt" or drop_type == "Tank Top":
        return "Top"
    if drop_type == "Pants" or drop_type == "Shorts":
        return "Bottom"
    return "Layer"


def row_to_subkind(row):
    drop_type = row['Type']
    if drop_type == "T-Shirt" or drop_type == "Shirt":
        pass
    elif drop_type == "Pants" or drop_type == "Shorts":
        pass
    elif drop_type == "Tank Top":
        drop_type = 'T-Shirt'
    else:
        drop_type = "Layer"
    exp = "Exp" if row['Exp'] else "Regular"
    return "{}/{}".format(drop_type, exp)


def object_type_to_kind(drop_type):
    if drop_type == "Backpack" or drop_type == "Bag" or drop_type == "Dopp Kit" \
       or drop_type == "Dufflebag" or drop_type == "Pouch":
        return "Bag"
    if drop_type == "Balaclava" or drop_type == "Bandana" or drop_type == "Scarf":
        return "Scarf/Bandana"
    if drop_type == "Cap" or drop_type == "Hat" or drop_type == "Hood":
        return "Headgear"
    if drop_type == "Bathrobe" or drop_type == "Robe" or drop_type == "Towel" \
       or drop_type == "Outerwear" or drop_type == "Keychain" or drop_type == "Socks":
        return "Misc"
    if drop_type == "Mask" or drop_type == "Belt":
        return drop_type     
    return "Misc"

# Define some reused frames
all_products_df = utils.drops_to_products(df_all, ['Year', 'Product'], 2022)
df_all['ColorCount'] = df_all['Colors'].str.split(',').dropna().apply(lambda d: len(d))

df_clothes = pd.DataFrame(df_all.loc[df_all['Category'] == 'Clothes', :])
df_clothes['Type'] = df_clothes['Type'].replace({'Sweatshirt':'Sweater'})
df_clothes["Kind"] = df_clothes['Type'].apply(type_to_kind)
df_clothes["Subkind"] = df_clothes.apply(row_to_subkind, axis=1)
clothes_products_df = utils.drops_to_products(df_clothes, ['Year', 'Product'], 2022)

df_objects = pd.DataFrame(df_all.loc[df_all['Category'] == 'Objects', :])
df_objects["Kind"] = df_objects['Type'].apply(object_type_to_kind)
objects_products_df = utils.drops_to_products(df_objects, ['Year', 'Product'], 2022)


kind_sort_order = ['Bottom', 'Top', 'Layer']
object_kind_sort_order = ['Bag', 'Mask', 'Scarf/Bandana', 'Headgear', 'Belt', 'Other']
year_sort = list(range(2021, 2012, -1))

# %%
df_2022 = df_all[df_all['Release'].dt.year == 2022]

# %%
from plots import product_summary_html

def fabric_summary_display(df_all, fabric):
    # Order by number of drops, not alphabetically
    # products = sorted(products)
    products = df_all[df_all['Fabric'] == fabric].groupby('Product').count()['Type'].sort_values(ascending=False).index
    if len(products) < 1:
        return
    htmls = [product_summary_html(df_all, p) for p in products]
    fragments = [f"<div class='product'>{h.data}</div>" for h in htmls]
    row = f"<h3>{fabric}</h3><div class='fabric-products' style='display: flex'>{' '.join(fragments)}</div>"
    display(HTML(row))

# %%
# Show in order of most-used to least-used fabric
# fabrics = sorted(df_2021['Fabric'].unique())
tdf = df_2022.groupby('Fabric').count()['Product'].reset_index()
tdf = tdf.sort_values(['Product', 'Fabric'], ascending=[False, True])
fabrics = tdf['Fabric']
for f in fabrics:
    fabric_summary_display(df_2022, f)
    
# TODO: do not need to see last drop, would be interesting to see first drop
# Out:
# <h3>Injected Linen</h3><div class='fabric-products' style='display: flex'><div class='product'><h4><a href='https://outlier.illposed.com/product/Experiment+314+-+Injex+Studio+Shirt'>Experiment 314 - Injex Studio Shirt</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-Experiment314-InjexStudioShirt-FabricImage-Flat.jpg?v=1657557469 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>333</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, NYD Sagebrush</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Experiment+335+-+Injex+Ones'>Experiment 335 - Injex Ones</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjexOnes-FabricImage-Black.jpg?v=1661355025 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>225</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injex+Raglan'>Injex Raglan</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-Experiment268-InjexRaglan-FabricImage-Fuchsia.jpg?v=1655217647 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>333</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, Black + White, NYD Dark Navy, NYD Fuchsia, NYD Tannic</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injex+Popover'>Injex Popover</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjexPopover-FabricImage-ColorUp.jpg?v=1656356677 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, GDX Burgundy Feels, GDX Concrete, GDX Graylight, GDX Ice Breathes, GDX Isola Teal, Raw White</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injex+Highdarts'>Injex Highdarts</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjexHighdarts-FabricImage-ColorUp.jpg?v=1652214253 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, GDX Concrete, GDX Dark Olive, GDX Graylight, GDX Sagebrush, GDX Tannic, GDX Winedark</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injex+Blazer'>Injex Blazer</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjectedLinenBlazer-FabricImage-black-front.jpg?v=1651505230 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>666</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, Raw White</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injex+Baggies'>Injex Baggies</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjexBaggies-FabricImage-ColorUp.jpg?v=1652195336 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, GDX Concrete, GDX Dark Oliver, GDX Isola Teal, GDX Sagebrush, GDX Tannic, GDX Winedark</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Injected+Linen+Pants'>Injected Linen Pants</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-InjectedLinenPants-FabricImage-GDXGrayLight.jpg?v=1651075070 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>Injected Linen</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>7</td>
# <h3>F. Cloth</h3><div class='fabric-products' style='display: flex'><div class='product'><h4><a href='https://outlier.illposed.com/product/Futuredarts'>Futuredarts</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-Futuredarts-FabricImage-GrayLight.jpg?v=1653502586 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>F. Cloth</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, Burgundy Feels, Charcoal, Concrete, Dark Navy, Dry Tan, Gray Light, Khaki Drab, Sagebrush, Sandstorm, Seascape</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Futureonethrees'>Futureonethrees</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Oultier-Experiment309-Futureonethrees-FabricImage-Black.jpg?v=1650309731 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>225</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>F. Cloth</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/Futureslimworks'>Futureslimworks</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-Futureslimworks-Fabric-Image-Concrete.jpg?v=1653501924 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>F. Cloth</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black, Charcoal, Concrete, Dark Navy, Dry Tan, Gray Light, Khaki Drab, Sagebrush, Sandstorm</td>
#     </tr>
#   </tbody>
# </table></div>     </div></div> <div class='product'><h4><a href='https://outlier.illposed.com/product/New+Way+Shorts'>New Way Shorts</a></h4>     <div style='display: flex;'>       <div class='product-image'><img width='100px' src=https://cdn.shopify.com/s/files/1/0065/5055/2666/products/201-Outlier-NewWayShorts-FabricImage-PopCOlors.jpg?v=1649100053 /></div>       <div class='product-table'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>last drop</th>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>number of drops</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>fabric</th>
#       <td>F. Cloth</td>
#     </tr>
#     <tr>
#       <th>number of colors</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>colors</th>
#       <td>Black,